# %% [markdown]
# 3.1 Problem - 1: Getting Started with Data Exploration - Some Warm up
# Exercises:**bold text**

# %% [markdown]
# 1. Data Exploration and Understanding:
# • Dataset Overview:
# 1. Load the dataset and display the first 10 rows.
# 2. Identify the number of rows and columns in the dataset.
# 3. List all the columns and their data types.
# • Basic Statistics:
# 1. Calculate the mean, median, and standard deviation for the Score column.
# 2. Identify the country with the highest and lowest happiness scores.
# • Missing Values:
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.
# • Filtering and Sorting:
# 1. Filter the dataset to show only the countries with a Score greater than 7.5.
# 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# top 10 rows.

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/WHR-2024-5CS037.csv')
df.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %%
#Determine the number of rows and columns in the dataset.
df_shape = df.shape
print(f"Number of rows: {df_shape[0]}, Number of columns: {df_shape[1]}")
# Out:
# Number of rows: 143, Number of columns: 9

# %%
# Display the columns along with their corresponding data types.
df.dtypes
# Out:
# Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %%
# Calculate mean, median, and standard deviation for the "Score" column
mean_score = df['score'].mean()
median_score = df['score'].median()
std_score = df['score'].std()

print(f"Mean Score: {mean_score}")
print(f"Median Score: {median_score}")
print(f"Standard Deviation of Score: {std_score}")
# Out:
# Mean Score: 5.52758041958042
# Median Score: 5.785
# Standard Deviation of Score: 1.1707165099442995

# %%
#Identifying the country with the highest and lowest happiness scores.
df[df['score'] == df['score'].max()] ['Country name']
# Out:
# 0    Finland
# Name: Country name, dtype: object

# %%
df[df['score'] == df['score'].min()] ['Country name']
# Out:
# 142    Afghanistan
# Name: Country name, dtype: object

# %%
#Checking if there are any missing values in the dataset. If so, display the total count for each column.
df.isnull().sum()
# Out:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %%
#Filtering the dataset to show only the countries with a Score greater than 7.5.
df[df['score'] > 7.5]['Country name']
# Out:
# 0    Finland
# 1    Denmark
# 2    Iceland
# Name: Country name, dtype: object

# %%
#For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the top 10 rows.
sorted_df = df.sort_values(by='Log GDP per capita', ascending=False)
country_names = sorted_df[['Country name', 'Log GDP per capita']].head(10)
country_names
# Out:
#                  Country name  Log GDP per capita
# 7                  Luxembourg               2.141
# 16                    Ireland               2.129
# 29                  Singapore               2.118
# 21       United Arab Emirates               1.983
# 8                 Switzerland               1.970
# 6                      Norway               1.952
# 22              United States               1.939
# 85  Hong Kong S.A.R. of China               1.909
# 1                     Denmark               1.908
# 5                 Netherlands               1.901

# %%
#Create a new column called Happiness Category that categorizes countries into three categories based on their Score:
df['Happiness Category'] = pd.cut(df['score'], bins = [-float('inf'),4,6,float('inf')],labels=['low', 'medium', 'high'])
df['Happiness Category']
# Out:
# 0      high
# 1      high
# 2      high
# 3      high
# 4      high
#        ...
# 138     low
# 139     low
# 140     low
# 141     low
# 142     low
# Name: Happiness Category, Length: 143, dtype: category
# Categories (3, object): ['low' < 'medium' < 'high']

# %% [markdown]
# **2. Data Visualizations:**
#
# • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.
#
# • Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.
#
# • Plot a histogram for the Score column to show its distribution and also
# interpret.
#
# • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
top_10_counries = df[['score','Country name']].sort_values(by='score',ascending=False).head(10)
top_10_counries.plot(kind='bar',x='Country name',y='score')
# Out:
# <Axes: xlabel='Country name'>

# %%
top_10_counries = df[['score','Country name']].sort_values(by='score',ascending=True).head(10)
top_10_counries.plot(kind='line',x='Country name',y='score')
# Out:
# <Axes: xlabel='Country name'>

# %%
df['score'].plot(kind='hist',edgecolor="black",bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['Log GDP per capita'], df['score'], color='skyblue', alpha=0.7)
plt.title('Relation between GDP per Capita and Happiness Score')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Happiness Score')
plt.grid(True)
plt.show()

# %% [markdown]
# **Problem - 2 - Some Advance Data Exploration Task:**
#
# Task - 1 - Setup Task - Preparing the South-Asia Dataset:
# Steps:
#
# 1. Define the countries in South Asia with a list for example:
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
#
#   "Maldives", "Nepal", "Pakistan", "Srilanka"]
#
#
# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
#
# 3. Save the filtered dataframe as separate CSV files for future use.

# %%
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"]
filtred = df[df['Country name'].isin(south_asian_countries)]
filtred.to_csv('/content/drive/MyDrive/asian_country.csv', index=False)

# %% [markdown]
# ### **Task - 2 - Composite Score Ranking:**
# Tasks:
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
#
# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support
#
# + 0.30 × Healthy Life Expectancy
# 2. Rank the South Asian countries based on the Composite Score in descending order.
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your
# discussion with some visualization plot.

# %%
south_asian = pd.read_csv('/content/drive/MyDrive/asian_country.csv')
south_asian
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 3    Sri Lanka  3.898               1.361           1.179
# 4   Bangladesh  3.886               1.122           0.249
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
# 5                    0.242                         0.000       0.091
#
#    Perceptions of corruption  Dystopia + residual Happiness Category
# ...

# %%
south_asian['composite_score'] = 0.40 * df['Log GDP per capita'] + 0.30 * df['Social support'] + 0.30 * df['Healthy life expectancy']
south_asian.sort_values(by='composite_score', ascending=False)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 2        India  4.054               1.166           0.653
# 1     Pakistan  4.657               1.069           0.600
# 3    Sri Lanka  3.898               1.361           1.179
# 0        Nepal  5.158               0.965           0.990
# 5  Afghanistan  1.721               0.628           0.000
# 4   Bangladesh  3.886               1.122           0.249
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 2                    0.417                         0.767       0.174
# 1                    0.321                         0.542       0.144
# 3                    0.586                         0.583       0.144
# 0                    0.443                         0.653       0.209
# 5                    0.242                         0.000       0.091
# 4                    0.513                         0.775       0.140
#
# ...

# %%
plt.figure(figsize=(10,6))
plt.bar(south_asian['Country name'], south_asian['composite_score'])
plt.xlabel('Composite Score')
plt.ylabel('Country Name')
plt.title('Top 5 Countries by Composite Score')
plt.show()

# %%
south_asian['original_rank']=south_asian['score'].rank(ascending=False)
south_asian['composite_rank']=south_asian['composite_score'].rank(ascending=False)
south_asian.head()
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 3    Sri Lanka  3.898               1.361           1.179
# 4   Bangladesh  3.886               1.122           0.249
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
#
#    Perceptions of corruption  Dystopia + residual Happiness Category  \
# 0                      0.115                1.783             medium
# ...

# %%
plt.figure(figsize=(12,6))
plt.scatter(south_asian['original_rank'],south_asian['composite_rank'],color="green")
plt.title("Rankings of South Asian countries")
plt.xlabel("Original Ranks")
plt.ylabel("Composite Ranks")
plt.show()

# %% [markdown]
# ### **Task - 3 - Outlier Detection:**
# Tasks:
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
# 2. Define outliers using the 1.5 × IQR rule.
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %%
def calculate_outlier_bounds(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return lower_bound, upper_bound

score_lower, score_upper = calculate_outlier_bounds(south_asian['score'])

gdp_lower, gdp_upper = calculate_outlier_bounds(south_asian['Log GDP per capita'])

south_asian['Outlier_Score'] = (south_asian['score'] < score_lower) | (south_asian['score'] > score_upper)
south_asian['Outlier_GDP'] = (south_asian['Log GDP per capita'] < gdp_lower) | (south_asian['Log GDP per capita'] > gdp_upper)
south_asian['Is_Outlier'] = south_asian['Outlier_Score'] | south_asian['Outlier_GDP']

outliers = south_asian[south_asian['Is_Outlier']]
print("Outlier Countries:")
print(outliers[['Country name', 'score', 'Log GDP per capita']])
# Out:
# Outlier Countries:
#   Country name  score  Log GDP per capita
# 5  Afghanistan  1.721               0.628

# %%
plt.figure(figsize=(10, 6))
plt.scatter(south_asian['Log GDP per capita'], south_asian['score'], label='Non-Outliers', color='blue')

plt.scatter(outliers['Log GDP per capita'], outliers['score'], label='Outliers', color='red')

plt.title('Scatter Plot: GDP per Capita vs. Score (South Asia)')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Score')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## **Task - 4 - Exploring Trends Across Metrics:**
# Tasks:
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
# {pearson correlation} with the Score for South Asian countries.
# 2. Create scatter plots with trendlines for these metrics against the Score.
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for
# South Asian countries.

# %%
freedom_corr = south_asian['score'].corr(south_asian['Freedom to make life choices'])
generosity_corr = south_asian['score'].corr(south_asian['Generosity'])

print(f"Correlation between Score & Freedom to Make Life Choices: {freedom_corr}")
print(f"Correlation between Score & Generosity: {generosity_corr}")
# Out:
# Correlation between Score & Freedom to Make Life Choices: 0.8005185224163315
# Correlation between Score & Generosity: 0.874512371253192

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.regplot(x='Freedom to make life choices', y='score', data=south_asian, scatter_kws={"color": "blue"}, line_kws={"color": "red"})
plt.title('Score vs Freedom')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')

# Plot 2: Score vs Generosity
plt.subplot(1, 2, 2)
sns.regplot(x='Generosity', y='score', data=south_asian, scatter_kws={"color": "green"}, line_kws={"color": "red"})
plt.title('Score vs Generosity')
plt.xlabel('Generosity')
plt.ylabel('Score')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Task - 5 - Gap Analysis:**
# Tasks:
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.
# 2. Rank the South Asian countries by this gap in both ascending and descending order.
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %%
south_asian['GDP-Score Gap'] = south_asian['Log GDP per capita'] - south_asian['score']
south_asian.sort_values(by='GDP-Score Gap', ascending=True)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
# 4   Bangladesh  3.886               1.122           0.249
# 3    Sri Lanka  3.898               1.361           1.179
# 5  Afghanistan  1.721               0.628           0.000
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
# 4                    0.513                         0.775       0.140
# 3                    0.586                         0.583       0.144
# 5                    0.242                         0.000       0.091
#
# ...

# %%
south_asian.sort_values(by='GDP-Score Gap', ascending=False)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 5  Afghanistan  1.721               0.628           0.000
# 3    Sri Lanka  3.898               1.361           1.179
# 4   Bangladesh  3.886               1.122           0.249
# 2        India  4.054               1.166           0.653
# 1     Pakistan  4.657               1.069           0.600
# 0        Nepal  5.158               0.965           0.990
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 5                    0.242                         0.000       0.091
# 3                    0.586                         0.583       0.144
# 4                    0.513                         0.775       0.140
# 2                    0.417                         0.767       0.174
# 1                    0.321                         0.542       0.144
# 0                    0.443                         0.653       0.209
#
# ...

# %%
plt.figure(figsize=(10, 6))
plt.bar(south_asian['Country name'], south_asian['GDP-Score Gap'])
plt.xlabel('Country Name')
plt.ylabel('GDP-Score Gap')
plt.title('Top 3 Countries with Largest Positive and Negative Gaps')
plt.show()

# %% [markdown]
# # **Problem - 3 - Comparative Analysis:**
# # **Task - 1 - Setup Task - Preparing the Middle Eastern Dataset:**
# **Tasks:**
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria","United Arab Emirates", "Yemen"]

# %%
middle_east_countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Oman", "State of Palestine", "Qatar",
                         "Saudi Arabia", "Syria","United Arab Emirates", "Yemen"]
middle_east_df = df[df['Country name'].isin(middle_east_countries)]
middle_east_df.to_csv('/content/drive/MyDrive/middle_east_country.csv', index=False)
middle_east_df
# Out:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 61                Bahrain  5.959                 NaN             NaN
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 102    State of Palestine  4.879                 NaN             NaN
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %% [markdown]
# # **Descriptive Statistics:**
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.
# • Which region has higher happiness Scores on average?

# %%
print("The mean of South Asia is: ",south_asian['score'].mean())
print("The mean of Middle East is: ",middle_east_df['score'].mean())
# Out:
# The mean of South Asia is:  3.895666666666667
# The mean of Middle East is:  5.363636363636363

# %% [markdown]
# ## **Top and Bottom Performers:**
# • Identify the top 3 and bottom 3 countries in each region based on the score.
#
# • Plot bar charts comparing these charts.

# %%
top_south_asian=south_asian.sort_values(by='score', ascending=False).head(3)
top_south_asian
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0        Nepal  5.158               0.965           0.990
# 1     Pakistan  4.657               1.069           0.600
# 2        India  4.054               1.166           0.653
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.443                         0.653       0.209
# 1                    0.321                         0.542       0.144
# 2                    0.417                         0.767       0.174
#
#    Perceptions of corruption  Dystopia + residual Happiness Category  \
# 0                      0.115                1.783             medium
# 1                      0.074                1.907             medium
# 2                      0.122                0.756             medium
#
#    composite_score  Outlier_Score  Outlier_GDP  Is_Outlier  GDP-Score Gap
# 0           1.4177          False        False       False         -4.193
# ...

# %%
bottom_south_asian=south_asian.sort_values(by='score', ascending=True).head(3)
bottom_south_asian
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 5  Afghanistan  1.721               0.628           0.000
# 4   Bangladesh  3.886               1.122           0.249
# 3    Sri Lanka  3.898               1.361           1.179
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 5                    0.242                         0.000       0.091
# 4                    0.513                         0.775       0.140
# 3                    0.586                         0.583       0.144
#
#    Perceptions of corruption  Dystopia + residual Happiness Category  \
# 5                      0.088                0.672                low
# 4                      0.167                0.919                low
# 3                      0.031                0.014                low
#
#    composite_score  Outlier_Score  Outlier_GDP  Is_Outlier  GDP-Score Gap
# 5           1.4108           True         True        True         -1.093
# ...

# %%
top_middle_east=middle_east_df.sort_values(by='score', ascending=False).head(3)
top_middle_east
# Out:
#             Country name  score  Log GDP per capita  Social support  \
# 4                 Israel  7.341               1.803           1.513
# 12                Kuwait  6.951               1.845           1.364
# 21  United Arab Emirates  6.733               1.983           1.164
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                     0.740                         0.641       0.153
# 12                    0.661                         0.827       0.200
# 21                    0.563                         0.815       0.209
#
#     Perceptions of corruption  Dystopia + residual Happiness Category
# 4                       0.193                2.298               high
# 12                      0.172                1.884               high
# 21                      0.258                1.741               high

# %%
bottom_middle_east=middle_east_df.sort_values(by='score', ascending=True).head(3)
bottom_middle_east
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 141      Lebanon  2.707               1.377           0.577
# 132        Yemen  3.561               0.671           1.281
# 124       Jordan  4.186               1.262           0.983
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 141                    0.556                         0.173       0.068
# 132                    0.293                         0.362       0.080
# 124                    0.594                         0.593       0.059
#
#      Perceptions of corruption  Dystopia + residual Happiness Category
# 141                      0.029               -0.073                low
# 132                      0.113                0.760                low
# 124                      0.189                0.504             medium

# %%
plt.figure(figsize=(10,6))
plt.bar(top_middle_east['Country name'],top_middle_east['score'],color='pink')
plt.bar(top_south_asian['Country name'],top_south_asian['score'],color='blue')
plt.xlabel('Country name')
plt.ylabel("Happiness score")
plt.title('Top 3 happies countries within South Asia and Middle East')
# Out:
# Text(0.5, 1.0, 'Top 3 happies countries within South Asia and Middle East')

# %%
data = {
    'Metric': ['Log GDP per capita', 'Social support', 'Healthy life expectancy'],
    'Middle East': [middle_east_df['Log GDP per capita'].mean(), middle_east_df['Social support'].mean(), middle_east_df['Healthy life expectancy'].mean()],
    'South Asia': [south_asian['Log GDP per capita'].mean(), south_asian['Social support'].mean(), south_asian['Healthy life expectancy'].mean()]
}
comparing_df = pd.DataFrame(data)
comparing_df.set_index('Metric', inplace=True)

comparing_df.plot(kind='bar', figsize=(10, 6), color=['skyblue', 'orange'])
plt.title('Comparison of Key Metrics Between Middle Eastern and South Asian Countries')
plt.ylabel('Values')
plt.legend(title='Region')

plt.grid()
plt.show()

# %% [markdown]
# ##4. Happiness Disparity:
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
# • Which region has greater variability in happiness?

# %%
max_south=south_asian['score'].max()
min_south=south_asian['score'].min()

print("Maximum score = ",max_south)
print("Minimum score = ",min_south)
# Out:
# Maximum score =  5.158
# Minimum score =  1.721

# %%
max_middle=middle_east_df['score'].max()
min_middle=middle_east_df['score'].min()

print("Maximum score = ",max_middle)
print("Minimum score = ",min_middle)
# Out:
# Maximum score =  7.341
# Minimum score =  2.707

# %%
south_asian_cv=(south_asian['score'].std()/south_asian['score'].mean())*100
middle_east_cv=(middle_east_df['score'].std()/middle_east_df['score'].mean())*100

print("Coefficient Variance South Asia = ", south_asian_cv)
print("Coefficient Variance Middle East = ", middle_east_cv)
# Out:
# Coefficient Variance South Asia =  30.21482883337427
# Coefficient Variance Middle East =  27.863516934944034

# %%
if(south_asian_cv > middle_east_cv):
  print("South asia has a greater variability in happiness.")
else:
  print("Middle East has a greater variability in happiness.")
# Out:
# South asia has a greater variability in happiness.

# %% [markdown]
# #5. Correlation Analysis:
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and Generosity within each region.
#
# • Create scatter plots to visualize and interpret the relationships.

# %%
south_freedom_corr = south_asian['score'].corr(south_asian['Freedom to make life choices'])
south_generosity_corr = south_asian['score'].corr(south_asian['Generosity'])

print(f"Correlation between Score & Freedom to Make Life Choices: {south_freedom_corr}")
print(f"Correlation between Score & Generosity: {south_generosity_corr}")
# Out:
# Correlation between Score & Freedom to Make Life Choices: 0.8005185224163315
# Correlation between Score & Generosity: 0.874512371253192

# %%
middle_freedom_corr = middle_east_df['score'].corr(middle_east_df['Freedom to make life choices'])
middle_generosity_corr = middle_east_df['score'].corr(middle_east_df['Generosity'])

print(f"Correlation between Score & Freedom to Make Life Choices: {middle_freedom_corr}")
print(f"Correlation between Score & Generosity: {middle_generosity_corr}")
# Out:
# Correlation between Score & Freedom to Make Life Choices: 0.8632202433827544
# Correlation between Score & Generosity: 0.6275236536964182

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(south_asian['Freedom to make life choices'], south_asian['score'], color='red')
plt.title('South Asian Score vs Freedom')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')

# Plot 2: Score vs Generosity
plt.subplot(1, 2, 2)
plt.scatter(south_asian['Generosity'], south_asian['score'], color='Green')
plt.title('South Asian Score vs Generosity')
plt.xlabel('Generosity')
plt.ylabel('Score')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(middle_east_df['Freedom to make life choices'], middle_east_df['score'], color='blue')
plt.title('South Asian Score vs Freedom')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')

# Plot 2: Score vs Generosity
plt.subplot(1, 2, 2)
plt.scatter(middle_east_df['Generosity'], middle_east_df['score'], color='orange')
plt.title('South Asian Score vs Generosity')
plt.xlabel('Generosity')
plt.ylabel('Score')

plt.tight_layout()
plt.show()

# %% [markdown]
# #6. Outlier Detection:
# • Identify outlier countries in both regions based on Score and GDP per Capita.
#
# • Plot these outliers and discuss their implications.

# %%
sa_score_lower, sa_score_upper = calculate_outlier_bounds(south_asian['score'])

sa_gdp_lower, sa_gdp_upper = calculate_outlier_bounds(south_asian['Log GDP per capita'])

south_asian['Outlier_Score'] = (south_asian['score'] < sa_score_lower) | (south_asian['score'] > sa_score_upper)
south_asian['Outlier_GDP'] = (south_asian['Log GDP per capita'] < sa_gdp_lower) | (south_asian['Log GDP per capita'] > sa_gdp_upper)
south_asian['Is_Outlier'] = south_asian['Outlier_Score'] | south_asian['Outlier_GDP']

sa_outliers = south_asian[south_asian['Is_Outlier']]
print("Outlier Countries:")
print(sa_outliers[['Country name', 'score', 'Log GDP per capita']])
# Out:
# Outlier Countries:
#   Country name  score  Log GDP per capita
# 5  Afghanistan  1.721               0.628

# %%
plt.figure(figsize=(10, 6))
plt.scatter(south_asian['Log GDP per capita'], south_asian['score'], label='Non-Outliers', color='blue')

plt.scatter(sa_outliers['Log GDP per capita'], sa_outliers['score'], label='Outliers', color='red')

plt.title('Scatter Plot: GDP per Capita vs. Score (South Asia)')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Score')
plt.legend()
plt.grid()
plt.show()

# %%
me_score_lower, me_score_upper = calculate_outlier_bounds(middle_east_df['score'])

me_gdp_lower, me_gdp_upper = calculate_outlier_bounds(middle_east_df['Log GDP per capita'])

middle_east_df['Outlier_Score'] = (middle_east_df['score'] < me_score_lower) | (middle_east_df['score'] > me_score_upper)
middle_east_df['Outlier_GDP'] = (middle_east_df['Log GDP per capita'] < me_gdp_lower) | (middle_east_df['Log GDP per capita'] > me_gdp_upper)
middle_east_df['Is_Outlier'] = middle_east_df['Outlier_Score'] | middle_east_df['Outlier_GDP']

me_outliers = middle_east_df[middle_east_df['Is_Outlier']]
print("Outlier Countries:")
print(me_outliers[['Country name', 'score', 'Log GDP per capita']])
# Out:
# Outlier Countries:
# Empty DataFrame
# Columns: [Country name, score, Log GDP per capita]
# Index: []
# <ipython-input-86-f99be6b4cf18>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   middle_east_df['Outlier_Score'] = (middle_east_df['score'] < me_score_lower) | (middle_east_df['score'] > me_score_upper)
# <ipython-input-86-f99be6b4cf18>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
plt.figure(figsize=(10, 6))
plt.scatter(middle_east_df['Log GDP per capita'], middle_east_df['score'], label='Non-Outliers', color='blue')
plt.scatter(me_outliers['Log GDP per capita'], me_outliers['score'], label='Outliers', color='red')

plt.title('Scatter Plot: GDP per Capita vs. Score (Middle East)')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Score')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #7. Visualization:
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
#
# • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
plt.figure(figsize = (10,6))
plt.boxplot([south_asian['score'], middle_east_df['score']], labels = ["South Asia", "Middle East"], patch_artist = True)

plt.title("Boxplot compaing the score distribution: South Asia vs Middle East")
plt.xlabel("Region")
plt.ylabel("Score")

plt.grid()
plt.show()
